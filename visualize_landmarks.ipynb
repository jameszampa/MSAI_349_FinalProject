# %%
import cv2
import json
from utils.read import read_landmarks
from utils.visualize import visualize_hand_landmarks

# %%
data = read_landmarks('hand_landmarks.json')

# %%
test_key, test_value = list(data.items())[0]
img = visualize_hand_landmarks(test_key, test_value)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
